# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
# df = pd.read_csv("https://storage.googleapis.com/second-try-ml/air-pollution/Train.csv")
df.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0           769.50            92                             11.000000
# 1          1319.85            91                             14.600000
# 2          1181.96            96                             16.400000
# 3          1113.67            96                              6.911948
# 4          1164.82            95                             13.900001
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle  \
# 0                          60.200001  ...                   38.593017
# 1                          48.799999  ...                   59.624912
# 2                          33.400002  ...                   49.839714
# 3                          21.300001  ...                   29.181258
# 4                          44.700001  ...                    0.797294
#
#    L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle  \
# 0                  -61.752587                  22.363665
# 1                  -67.693509                  28.614804
# 2                  -78.342701                  34.296977
# 3                  -73.896588                  30.545446
# 4                  -68.612480                  26.899694
#
#    L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height  \
# 0                                    1793.793579            3227.855469
# 1                                    1789.960449            3384.226562
# 2                                            NaN                    NaN
# 3                                            NaN                    NaN
# 4                                            NaN                    NaN
#
#    L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle  \
# 0                      0.010579                    74.481049
# 1                      0.015104                    75.630043
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#    L3_CH4_sensor_zenith_angle  L3_CH4_solar_azimuth_angle  \
# 0                   37.501499                  -62.142639
# 1                   55.657486                  -53.868134
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    L3_CH4_solar_zenith_angle
# 0                  22.545118
# 1                  19.293652
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 82 columns]

# %%
RSEED = 42

# %%
X = df.drop("target", axis=1)
y = df.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, shuffle=True, random_state=RSEED)
df_train = pd.concat([X_train, y_train], axis=1)
df_train
# Out:
#             Place_ID X Date        Date Place_ID  target_min  target_max  \
# 19308  KYNZWCA X 2020-03-10  2020-03-10  KYNZWCA         4.0        61.0
# 7260   7DRFQCK X 2020-03-08  2020-03-08  7DRFQCK         3.0        55.0
# 16434  HCGAOBY X 2020-01-23  2020-01-23  HCGAOBY         1.0        59.0
# 29088  WQP8SI3 X 2020-03-15  2020-03-15  WQP8SI3         9.0       154.0
# 21019  NMX4N9O X 2020-03-12  2020-03-12  NMX4N9O         3.0        30.0
# ...                     ...         ...      ...         ...         ...
# 29802  YAXBMZ6 X 2020-02-16  2020-02-16  YAXBMZ6         6.0       146.0
# 5390   5I4TI4R X 2020-03-19  2020-03-19  5I4TI4R        12.0        60.0
# 860    0PP73FZ X 2020-02-20  2020-02-20  0PP73FZ        61.0       187.0
# 15795  GP8V3PO X 2020-01-24  2020-01-24  GP8V3PO        34.0       153.0
# 23654  RFQQX9G X 2020-01-23  2020-01-23  RFQQX9G         1.0        53.0
#
#        target_variance  target_count  precipitable_water_entire_atmosphere  \
# 19308          1726.84            61                             16.518541
# 7260           2115.89           168                              3.186504
# 16434          1805.71           131                             21.300001
# 29088         18066.50            94                              6.800000
# 21019           424.18            22                             18.100000
# ...                ...           ...                                   ...
# 29802          7860.44           106                              8.600000
# 5390           1862.22            19                              6.300000
# 860            1430.51           726                             19.140839
# 15795          6662.07           140                             16.233334
# 23654          1249.79           179                             18.754545
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 19308                          63.600002                           0.006580
# 7260                           57.642859                           0.001815
# 16434                          95.000000                           0.009622
# 29088                          56.625000                           0.002695
# 21019                          93.300003                           0.007409
# ...                                  ...                                ...
# 29802                          71.700005                           0.002200
# 5390                           74.200005                           0.003360
# 860                            61.799999                           0.005157
# 15795                          87.700005                           0.006430
# 23654                          89.809094                           0.005171
#
#        ...  L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle  \
# 19308  ...                  -39.126728                  41.704754
# 7260   ...                   66.413640                  69.282032
# 16434  ...                 -151.809550                  54.043725
# 29088  ...                 -173.270797                  40.071048
# 21019  ...                  -14.253807                  52.796998
# ...    ...                         ...                        ...
# 29802  ...                 -174.690284                  50.855477
# 5390   ...                 -172.787322                  38.104149
# 860    ...                         NaN                        NaN
# 15795  ...                 -162.096101                  60.725879
# 23654  ...                         NaN                        NaN
#
#        L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height  \
# 19308                                            NaN                    NaN
# 7260                                             NaN                    NaN
# 16434                                            NaN                    NaN
# 29088                                            NaN                    NaN
# 21019                                            NaN                    NaN
# ...                                              ...                    ...
# 29802                                            NaN                    NaN
# 5390                                             NaN                    NaN
# 860                                              NaN                    NaN
# 15795                                            NaN                    NaN
# 23654                                            NaN                    NaN
#
#        L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle  \
# 19308                           NaN                          NaN
# 7260                            NaN                          NaN
# 16434                           NaN                          NaN
# 29088                           NaN                          NaN
# 21019                           NaN                          NaN
# ...                             ...                          ...
# 29802                           NaN                          NaN
# 5390                            NaN                          NaN
# 860                             NaN                          NaN
# 15795                           NaN                          NaN
# 23654                           NaN                          NaN
#
#        L3_CH4_sensor_zenith_angle  L3_CH4_solar_azimuth_angle  \
# 19308                         NaN                         NaN
# 7260                          NaN                         NaN
# 16434                         NaN                         NaN
# 29088                         NaN                         NaN
# 21019                         NaN                         NaN
# ...                           ...                         ...
# 29802                         NaN                         NaN
# 5390                          NaN                         NaN
# 860                           NaN                         NaN
# 15795                         NaN                         NaN
# 23654                         NaN                         NaN
#
#        L3_CH4_solar_zenith_angle  target
# 19308                        NaN    22.0
# 7260                         NaN    18.0
# 16434                        NaN    17.0
# 29088                        NaN    63.0
# 21019                        NaN    16.0
# ...                          ...     ...
# 29802                        NaN    58.0
# 5390                         NaN    32.0
# 860                          NaN   155.0
# 15795                        NaN    85.0
# 23654                        NaN    10.0
#
# [21389 rows x 82 columns]

# %%
df_train["Date"].unique()
# conclusion: Dataset contains the first quartal of the year Jan-march) -- Winter in the north, summer in the south
# Out:
# array(['2020-03-10', '2020-03-08', '2020-01-23', '2020-03-15',
#        '2020-03-12', '2020-01-25', '2020-03-27', '2020-03-25',
#        '2020-02-14', '2020-02-26', '2020-02-13', '2020-02-28',
#        '2020-04-01', '2020-01-04', '2020-02-23', '2020-01-31',
#        '2020-01-24', '2020-04-04', '2020-03-19', '2020-03-30',
#        '2020-01-20', '2020-03-06', '2020-02-19', '2020-01-30',
#        '2020-02-21', '2020-02-18', '2020-02-27', '2020-01-06',
#        '2020-01-21', '2020-02-09', '2020-03-05', '2020-02-12',
#        '2020-03-26', '2020-01-03', '2020-01-26', '2020-03-09',
#        '2020-02-17', '2020-03-18', '2020-01-02', '2020-02-15',
#        '2020-02-04', '2020-01-10', '2020-03-13', '2020-02-24',
#        '2020-02-11', '2020-03-03', '2020-01-22', '2020-04-02',
#        '2020-03-24', '2020-01-29', '2020-03-02', '2020-03-28',
#        '2020-02-20', '2020-01-16', '2020-01-28', '2020-02-01',
#        '2020-03-20', '2020-03-16', '2020-02-25', '2020-01-15',
#        '2020-02-08', '2020-01-05', '2020-02-05', '2020-01-19',
#        '2020-03-21', '2020-02-07', '2020-01-12', '2020-02-22',
#        '2020-03-14', '2020-01-27', '2020-02-02', '2020-01-07',
#        '2020-03-23', '2020-03-11', '2020-03-31', '2020-01-08',
#        '2020-03-29', '2020-03-22', '2020-01-14', '2020-02-10',
#        '2020-01-18', '2020-03-17', '2020-04-03', '2020-03-07',
#        '2020-01-13', '2020-01-11', '2020-02-29', '2020-02-06',
#        '2020-01-17', '2020-02-03', '2020-03-04', '2020-01-09',
#        '2020-03-01', '2020-02-16'], dtype=object)

# %%
df_train.shape[0]
# Out:
# 21389

# %%
df_train["ordinal_date"] = df_train.Date.astype("datetime64").apply(lambda x: x.toordinal())
df_train.Date.nunique()
# Out:
# 94

# %%
df_train.ordinal_date
# Out:
# 19308    737494
# 7260     737492
# 16434    737447
# 29088    737499
# 21019    737496
#           ...
# 29802    737471
# 5390     737503
# 860      737475
# 15795    737448
# 23654    737447
# Name: ordinal_date, Length: 21389, dtype: int64

# %% [markdown]
# Data is over 3 months, therefore 94 days seem reasonable

# %%
df_train.Place_ID.nunique()
# Out:
# 340

# %%
my_place = df_train.Place_ID.unique()[-2]
my_place
# Out:
# 'R9PQN4I'

# %%
sns.scatterplot(data=df_train, x="Place_ID", y="target")
# Out:
# <Axes: xlabel='Place_ID', ylabel='target'>

# %% [markdown]
# target is location dependent

# %%
sns.scatterplot(data=df_train, x="ordinal_date", y="target")
# Out:
# <Axes: xlabel='ordinal_date', ylabel='target'>

# %% [markdown]
# target depends on date

# %%
fig, ax = plt.subplots(figsize=(18,4))
sns.lineplot(data=df_train.query("Place_ID == @my_place").sort_values("Date"), x="Date", y="target", ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=80)
# Out:
# C:\Users\soa\AppData\Local\Temp\ipykernel_15712\1141517341.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=80)
# [Text(0, 0, '2020-01-02'),
#  Text(1, 0, '2020-01-03'),
#  Text(2, 0, '2020-01-04'),
#  Text(3, 0, '2020-01-05'),
#  Text(4, 0, '2020-01-07'),
#  Text(5, 0, '2020-01-08'),
#  Text(6, 0, '2020-01-09'),
#  Text(7, 0, '2020-01-10'),
#  Text(8, 0, '2020-01-11'),
#  Text(9, 0, '2020-01-12'),
#  Text(10, 0, '2020-01-13'),
#  Text(11, 0, '2020-01-14'),
#  Text(12, 0, '2020-01-18'),
#  Text(13, 0, '2020-01-19'),
#  Text(14, 0, '2020-01-21'),
#  Text(15, 0, '2020-01-23'),
#  Text(16, 0, '2020-01-24'),
#  Text(17, 0, '2020-02-03'),
#  Text(18, 0, '2020-02-04'),
#  Text(19, 0, '2020-02-05'),
#  Text(20, 0, '2020-02-06'),
#  Text(21, 0, '2020-02-09'),
#  Text(22, 0, '2020-03-06'),
#  Text(23, 0, '2020-03-07'),
#  Text(24, 0, '2020-03-08'),
#  Text(25, 0, '2020-03-09'),
#  Text(26, 0, '2020-03-11'),
#  Text(27, 0, '2020-03-12'),
#  Text(28, 0, '2020-03-13'),
#  Text(29, 0, '2020-03-16'),
#  Text(30, 0, '2020-03-17'),
#  Text(31, 0, '2020-03-19'),
#  Text(32, 0, '2020-03-21'),
#  Text(33, 0, '2020-03-22'),
#  Text(34, 0, '2020-03-23'),
#  Text(35, 0, '2020-03-24'),
#  Text(36, 0, '2020-03-25'),
#  Text(37, 0, '2020-03-27'),
#  Text(38, 0, '2020-03-28'),
#  Text(39, 0, '2020-03-30'),
#  Text(40, 0, '2020-03-31'),
#  Text(41, 0, '2020-04-01'),
#  Text(42, 0, '2020-04-03'),
#  Text(43, 0, '2020-04-04')]

# %% [markdown]
# high fluctuation form day to day, but mean is dependent on time

# %%
df_train["wind_speed"] = df_train.apply(lambda x: np.sqrt(x["u_component_of_wind_10m_above_ground"]**2 + x["v_component_of_wind_10m_above_ground"]**2), axis=1)
df_train.wind_speed
# Out:
# 19308    2.063767
# 7260     3.767556
# 16434    0.416769
# 29088    4.747506
# 21019    2.947030
#            ...
# 29802    1.775082
# 5390     3.765251
# 860      1.911968
# 15795    2.387840
# 23654    4.026328
# Name: wind_speed, Length: 21389, dtype: float64

# %%
cols_short = [col for col in df_train.columns if not "angle" in col \
     and not "sensor" in col \
     and not "ID" in col \
     and not "Date" in col \
     and not "target_" in col \
     and not "water" in col \
     and not "_of_wind" in col \
     and not "CH4" in col]
cols_short
# Out:
# ['relative_humidity_2m_above_ground',
#  'specific_humidity_2m_above_ground',
#  'temperature_2m_above_ground',
#  'L3_NO2_NO2_column_number_density',
#  'L3_NO2_NO2_slant_column_number_density',
#  'L3_NO2_absorbing_aerosol_index',
#  'L3_NO2_cloud_fraction',
#  'L3_NO2_stratospheric_NO2_column_number_density',
#  'L3_NO2_tropopause_pressure',
#  'L3_NO2_tropospheric_NO2_column_number_density',
#  'L3_O3_O3_column_number_density',
#  'L3_O3_O3_effective_temperature',
#  'L3_O3_cloud_fraction',
#  'L3_CO_CO_column_number_density',
#  'L3_CO_H2O_column_number_density',
#  'L3_CO_cloud_height',
#  'L3_HCHO_HCHO_slant_column_number_density',
#  'L3_HCHO_cloud_fraction',
#  'L3_HCHO_tropospheric_HCHO_column_number_density',
#  'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#  'L3_CLOUD_cloud_base_height',
#  'L3_CLOUD_cloud_base_pressure',
#  'L3_CLOUD_cloud_fraction',
#  'L3_CLOUD_cloud_optical_depth',
#  'L3_CLOUD_cloud_top_height',
#  'L3_CLOUD_cloud_top_pressure',
#  'L3_CLOUD_surface_albedo',
#  'L3_AER_AI_absorbing_aerosol_index',
#  'L3_SO2_SO2_column_number_density',
#  'L3_SO2_SO2_column_number_density_amf',
#  'L3_SO2_SO2_slant_column_number_density',
#  'L3_SO2_absorbing_aerosol_index',
#  'L3_SO2_cloud_fraction',
#  'target',
#  'ordinal_date',
#  'wind_speed']

# %% [markdown]
# replace wind components with total speed

# %%
sns.heatmap(df_train[cols_short].isna())
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer
from sklearn import set_config
set_config(transform_output="pandas")

# %%
imputer = SimpleImputer(strategy="median")
df_imp = imputer.fit_transform(df_train[cols_short])

# %%
df_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21389 entries, 19308 to 23654
# Data columns (total 36 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   relative_humidity_2m_above_ground                    21389 non-null  float64
#  1   specific_humidity_2m_above_ground                    21389 non-null  float64
#  2   temperature_2m_above_ground                          21389 non-null  float64
#  3   L3_NO2_NO2_column_number_density                     21389 non-null  float64
#  4   L3_NO2_NO2_slant_column_number_density               21389 non-null  float64
#  5   L3_NO2_absorbing_aerosol_index                       21389 non-null  float64
#  6   L3_NO2_cloud_fraction                                21389 non-null  float64
#  7   L3_NO2_stratospheric_NO2_column_number_density       21389 non-null  float64
#  8   L3_NO2_tropopause_pressure                           21389 non-null  float64
#  9   L3_NO2_tropospheric_NO2_column_number_density        21389 non-null  float64
#  10  L3_O3_O3_column_number_density                       21389 non-null  float64
#  11  L3_O3_O3_effective_temperature                       21389 non-null  float64
#  12  L3_O3_cloud_fraction                                 21389 non-null  float64
#  13  L3_CO_CO_column_number_density                       21389 non-null  float64
#  14  L3_CO_H2O_column_number_density                      21389 non-null  float64
#  15  L3_CO_cloud_height                                   21389 non-null  float64
#  16  L3_HCHO_HCHO_slant_column_number_density             21389 non-null  float64
#  17  L3_HCHO_cloud_fraction                               21389 non-null  float64
#  18  L3_HCHO_tropospheric_HCHO_column_number_density      21389 non-null  float64
#  19  L3_HCHO_tropospheric_HCHO_column_number_density_amf  21389 non-null  float64
#  20  L3_CLOUD_cloud_base_height                           21389 non-null  float64
#  21  L3_CLOUD_cloud_base_pressure                         21389 non-null  float64
#  22  L3_CLOUD_cloud_fraction                              21389 non-null  float64
#  23  L3_CLOUD_cloud_optical_depth                         21389 non-null  float64
#  24  L3_CLOUD_cloud_top_height                            21389 non-null  float64
#  25  L3_CLOUD_cloud_top_pressure                          21389 non-null  float64
#  26  L3_CLOUD_surface_albedo                              21389 non-null  float64
#  27  L3_AER_AI_absorbing_aerosol_index                    21389 non-null  float64
#  28  L3_SO2_SO2_column_number_density                     21389 non-null  float64
#  29  L3_SO2_SO2_column_number_density_amf                 21389 non-null  float64
#  30  L3_SO2_SO2_slant_column_number_density               21389 non-null  float64
#  31  L3_SO2_absorbing_aerosol_index                       21389 non-null  float64
#  32  L3_SO2_cloud_fraction                                21389 non-null  float64
#  33  target                                               21389 non-null  float64
#  34  ordinal_date                                         21389 non-null  float64
#  35  wind_speed                                           21389 non-null  float64
# dtypes: float64(36)
# memory usage: 6.0 MB

# %%
df_imp.head(6)
# Out:
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 19308                          63.600002                           0.006580
# 7260                           57.642859                           0.001815
# 16434                          95.000000                           0.009622
# 29088                          56.625000                           0.002695
# 21019                          93.300003                           0.007409
# 925                            81.700005                           0.006859
#
#        temperature_2m_above_ground  L3_NO2_NO2_column_number_density  \
# 19308                    14.496118                          0.000065
# 7260                     -2.886062                          0.000045
# 16434                    13.973047                          0.000078
# 29088                     2.766779                          0.000053
# 21019                    10.274438                          0.000079
# 925                      11.477502                          0.000060
#
#        L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index  \
# 19308                                0.000134                       -1.751167
# 7260                                 0.000185                       -1.157417
# 16434                                0.000176                       -0.914185
# 29088                                0.000152                       -1.888738
# 21019                                0.000140                       -1.520739
# 925                                  0.000150                       -1.223717
#
#        L3_NO2_cloud_fraction  L3_NO2_stratospheric_NO2_column_number_density  \
# 19308               0.070823                                        0.000055
# 7260                0.467880                                        0.000035
# 16434               0.026662                                        0.000036
# 29088               0.306814                                        0.000055
# 21019               0.403888                                        0.000035
# 925                 0.121882                                        0.000037
#
#        L3_NO2_tropopause_pressure  \
# 19308                13050.637454
# 7260                 22060.528945
# 16434                11204.568959
# 29088                24053.252781
# 21019                16664.098604
# 925                   7311.869141
#
#        L3_NO2_tropospheric_NO2_column_number_density  ...  \
# 19308                                       0.000012  ...
# 7260                                        0.000012  ...
# 16434                                       0.000043  ...
# 29088                                       0.000010  ...
# 21019                                       0.000023  ...
# 925                                         0.000022  ...
#
#        L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# 19308                 0.198105                          -1.751164
# 7260                  0.241965                          -1.154776
# 16434                 0.181240                          -0.914185
# 29088                 0.140434                          -1.888747
# 21019                 0.265076                          -1.506303
# 925                   0.203378                          -1.223717
#
#        L3_SO2_SO2_column_number_density  L3_SO2_SO2_column_number_density_amf  \
# 19308                          0.000059                              0.330969
# 7260                           0.000407                              0.395603
# 16434                          0.000472                              0.215672
# 29088                         -0.000249                              0.459593
# 21019                         -0.000306                              0.265232
# 925                            0.000330                              0.416791
#
#        L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 19308                                0.000017                       -2.454729
# 7260                                 0.000192                       -2.225702
# 16434                                0.000110                       -1.418435
# 29088                               -0.000112                       -2.361639
# 21019                               -0.000079                       -1.948378
# 925                                  0.000134                       -1.524437
#
#        L3_SO2_cloud_fraction  target  ordinal_date  wind_speed
# 19308               0.084721    22.0      737494.0    2.063767
# 7260                0.215436    18.0      737492.0    3.767556
# 16434               0.157044    17.0      737447.0    0.416769
# 29088               0.357849    63.0      737499.0    4.747506
# 21019               0.398801    16.0      737496.0    2.947030
# 925                 0.201906   168.0      737449.0    1.266840
#
# [6 rows x 36 columns]

# %%
nonL3_cols = [col for col in cols_short if not 'L3' in col]
nonL3_cols
# Out:
# ['relative_humidity_2m_above_ground',
#  'specific_humidity_2m_above_ground',
#  'temperature_2m_above_ground',
#  'target',
#  'ordinal_date',
#  'wind_speed']

# %%
sns.pairplot(df_imp[nonL3_cols], height=1.5)

# %%
NO2_cols = [col for col in cols_short if "NO2" in col]
NO2_cols.append("target")

# %%
sns.pairplot(df_imp[NO2_cols], height=1.5)

# %%
df_imp.shape[1]
# Out:
# 36

# %%
fig = plt.figure(figsize=(12,12))
for i, col in enumerate(df_imp.columns):
    fig.add_subplot(6,6, i+1)
    sns.boxplot(data=df_imp, y=col)
fig.tight_layout()

# %%
fig = plt.figure(figsize=(12,12))
for i, col in enumerate(df_imp.columns):
    ax = fig.add_subplot(6,6, i+1)
    ax.set_yscale("log")
    sns.boxplot(data=df_imp, y=col, ax=ax)
fig.tight_layout()

# %% [markdown]
# all features are and target is numerical --> regression
